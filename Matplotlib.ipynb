# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %% [markdown]
# # MATPLOTLIB

# %%
# Importing the sales data

sales_data = pd.read_csv("Fashion_Retail_Sales.csv")
print(sales_data)
# Out:
#       Customer Reference ID Item Purchased  Purchase Amount (USD)  \
# 0                      4018        Handbag                 4619.0
# 1                      4115          Tunic                 2456.0
# 2                      4019       Tank Top                 2102.0
# 3                      4097       Leggings                 3126.0
# 4                      3997         Wallet                 3003.0
# ...                     ...            ...                    ...
# 3395                   4118         Shorts                   37.0
# 3396                   4056       Slippers                  176.0
# 3397                   3991         Onesie                    NaN
# 3398                   4042        Sandals                  128.0
# 3399                   4001       Backpack                  115.0
#
#      Date Purchase  Review Rating Payment Method
# 0       05-02-2023            NaN    Credit Card
# 1       11-07-2023            2.0    Credit Card
# ...

# %%
sales_data.shape
# Out:
# (3400, 6)

# %%
sales_data.columns
# Out:
# Index(['Customer Reference ID', 'Item Purchased', 'Purchase Amount (USD)',
#        'Date Purchase', 'Review Rating', 'Payment Method'],
#       dtype='object')

# %%
sales_data.index
# Out:
# RangeIndex(start=0, stop=3400, step=1)

# %%
sales_data.describe()
# Out:
#        Customer Reference ID  Purchase Amount (USD)  Review Rating
# count            3400.000000            2750.000000    3076.000000
# mean             4039.660588             156.709818       2.999057
# std                48.122583             419.536669       1.156505
# min              3957.000000              10.000000       1.000000
# 25%              3997.000000              57.000000       2.000000
# 50%              4040.000000             110.000000       3.000000
# 75%              4081.000000             155.750000       4.000000
# max              4122.000000            4932.000000       5.000000

# %%
sales_data.head()
# Out:
#    Customer Reference ID Item Purchased  Purchase Amount (USD) Date Purchase  \
# 0                   4018        Handbag                 4619.0    05-02-2023
# 1                   4115          Tunic                 2456.0    11-07-2023
# 2                   4019       Tank Top                 2102.0    23-03-2023
# 3                   4097       Leggings                 3126.0    15-03-2023
# 4                   3997         Wallet                 3003.0    27-11-2022
#
#    Review Rating Payment Method
# 0            NaN    Credit Card
# 1            2.0    Credit Card
# 2            4.1           Cash
# 3            3.2           Cash
# 4            4.7           Cash

# %% [markdown]
# # Basic Methods

# %%
plt.plot(sales_data["Item Purchased"] , sales_data["Purchase Amount (USD)"])
plt.title("Item Sales")
plt.xlabel("Item Purchased")
plt.ylabel("Purchase Amount")
# Out:
# Text(0, 0.5, 'Purchase Amount')

# %%
plt.scatter(sales_data["Item Purchased"] , sales_data["Purchase Amount (USD)"])
plt.title("Item Sales")
plt.xlabel("Item Purchased")
plt.ylabel("Purchase Amount")
# Out:
# Text(0, 0.5, 'Purchase Amount')

# %%
plt.bar(sales_data["Item Purchased"] , sales_data["Purchase Amount (USD)"])
plt.title("Item Sales")
plt.xlabel("Item Purchased")
plt.ylabel("Purchase Amount")
# Out:
# Text(0, 0.5, 'Purchase Amount')

# %%
plt.hist(sales_data["Payment Method"])
plt.title("Item Sales")
plt.xlabel("Item Purchased")
plt.ylabel("Purchase Amount")
# Out:
# Text(0, 0.5, 'Purchase Amount')

# %%
plt.pie(sales_data["Purchase Amount (USD)"] , labels=["Item Purchased"])
plt.title("Item Sales")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 plt.pie(sales_data["Purchase Amount (USD)"] , labels=["Item Purchased"])
#       2 plt.title("Item Sales")
#
# File c:\Users\SANJAY LADE\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\_api\deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# ...

# %%
plt.boxplot(sales_data["Item Purchased"] , sales_data["Purchase Amount (USD)"])
plt.title("Item Sales")
# Out:
# C:\Users\SANJAY LADE\AppData\Local\Temp\ipykernel_14732\2945717018.py:1: MatplotlibDeprecationWarning: Passing the notch parameter of boxplot() positionally is deprecated since Matplotlib 3.10; the parameter will become keyword-only in 3.12.
#   plt.boxplot(sales_data["Item Purchased"] , sales_data["Purchase Amount (USD)"])
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 plt.boxplot(sales_data["Item Purchased"] , sales_data["Purchase Amount (USD)"])
#       2 plt.title("Item Sales")
#
# File c:\Users\SANJAY LADE\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\_api\deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
# ...

# %% [markdown]
# # Important Styling Methods

# %%
plt.scatter(sales_data["Item Purchased"] , sales_data["Purchase Amount (USD)"])
plt.title("Item Sales")
plt.xlabel("Item Purchased")
plt.ylabel("Purchase Amount")
plt.grid(True)
plt.Figure(figsize=(8,5))

# %% [markdown]
# # Subplots

# %%
# fig = complete box , ax = every single box 
fig, ax = plt.subplots(2,2, figsize=(10,6))
fig.suptitle("Product Sales Dashboard")

# First section
ax[0,0].bar(product_sales["Product"], product_sales["Online_Sales"])
ax[0,0].set_title("Online Sales")
ax[0,0].set_xlabel("Product")
ax[0,0].set_ylabel("Units Sold")

# Second section
ax[0,1].bar(product_sales["Product"], product_sales["Offline_Sales"])
ax[0,1].set_title("Offline Sales")

# Third section 
ax[1,0].pie(product_sales["Offline_Sales"] , labels = product_sales["Product"])
ax[1,0].set_title("Sales Data")

# Fourth section
ax[1,1].plot(product_sales["Product"], product_sales["Online_Sales"], label="Online")
ax[1,1].plot(product_sales["Product"], product_sales["Offline_Sales"], label="Offline")
ax[1,1].set_title("Online vs Offline")
ax[1,1].legend()

plt.tight_layout()
plt.show()

# %%
# Saving the figures 
fig.savefig("Grapgh.jpeg" , dpi = 200)

# %%
# OO Way
x = [1,2,3,4]
y = [10,20,25,30]

fig, ax = plt.subplots()

ax.plot(x, y)
ax.set_title("Sales Growth")
ax.set_xlabel("Days")
ax.set_ylabel("Sales")

plt.show()

# %% [markdown]
# # Working With Images

# %%
# Reading image 
img = mpimg.imread("Airbrush-IMAGE-ENHANCER-1768631769364-1768631769364.jpg")
plt.imshow(img , cmap = 'gray')
plt.axis('off')
plt.show()

# %%
# Crop Image
cropped = img[500 : 700 , 200 : 400]
plt.imshow(cropped)
plt.show()

# %%
# Changing the brightnes 
plt.imshow(img*0.01)
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..1.55].
