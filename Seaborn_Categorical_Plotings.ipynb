# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Categorical Plotings

# %%
sales_data = pd.read_csv("Fashion_Retail_Sales.csv")
df = pd.DataFrame(sales_data)
print(df)
# Out:
#       Customer Reference ID Item Purchased  Purchase Amount (USD)  \
# 0                      4018        Handbag                 4619.0
# 1                      4115          Tunic                 2456.0
# 2                      4019       Tank Top                 2102.0
# 3                      4097       Leggings                 3126.0
# 4                      3997         Wallet                 3003.0
# ...                     ...            ...                    ...
# 3395                   4118         Shorts                   37.0
# 3396                   4056       Slippers                  176.0
# 3397                   3991         Onesie                    NaN
# 3398                   4042        Sandals                  128.0
# 3399                   4001       Backpack                  115.0
#
#      Date Purchase  Review Rating Payment Method
# 0       05-02-2023            NaN    Credit Card
# 1       11-07-2023            2.0    Credit Card
# ...

# %%
# CountPlot
sns.countplot(data=df , x = "Item Purchased")
plt.xticks(rotation=90)  
plt.tight_layout()
plt.show()

# %%
# BarPlot
sns.barplot(data=df , x = "Item Purchased", y = 'Payment Method')
plt.xticks(rotation=90)  
plt.tight_layout()
plt.show()

# %%
# BoxPlot
sns.boxplot(data=df , y = "Item Purchased" , x ="Payment Method" , color='red')
plt.xticks(rotation=90)  
plt.tight_layout()
plt.show()

# %%
# ViolinPlot
sns.stripplot(data=df , x = "Item Purchased", y = "Payment Method")
plt.xticks(rotation=90)  
plt.tight_layout()
plt.show()

# %%
# SwarmPlot
sns.swarmplot(data=df , x = "Item Purchased" , y = "Payment Method")
plt.xticks(rotation=90)  
plt.tight_layout()
plt.show()
# Out:
# c:\Users\SANJAY LADE\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 97.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\SANJAY LADE\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 96.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\SANJAY LADE\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 97.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
# PointPlot
sns.pointplot(data=df , x = "Item Purchased" , y = "Payment Method")
plt.xticks(rotation=90)  
plt.tight_layout()
plt.show()
